# %% [markdown]
# From VENUES_DIR to EXTRACTED_VENUES

# %%
FRSQ_OUTPUT_PATH ='../data/output/frsq/'
VENUES_DIR = FRSQ_OUTPUT_PATH+'raw_venues/'

EXTRACTED_VENUES = FRSQ_OUTPUT_PATH+'frsq_extracted_venues.geojson'
import glob
import csv
import json
from ast import literal_eval
import json
import geopandas as gp

# %%
import pandas as pd
from pandas.io.json import json_normalize
from IPython.display import display
TARGET_KEYS = ['id', 'name', 'location', 'categories', 'verified', 'stats']
all_venues = []
import json
for fn in glob.glob(VENUES_DIR+'*.txt'):
    print fn
    with open(fn) as f:
        for line in f:
            swne, vcnt, data = line.split('\t')
            data = literal_eval(data)
            venues = data['venues']
            if venues:
                print json.dumps(venues,indent=4)
            all_venues.extend(venues)
            break

len(all_venues)
# Out:
# ../data/output/frsq/raw_venues\10000.txt
# ../data/output/frsq/raw_venues\12000.txt
# [
#     {
#         "verified": false,
#         "name": "Oki Bowl DC & Sake",
#         "allowMenuUrlEdit": true,
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Noodle Houses",
#                 "primary": true,
#                 "name": "Noodle House",
#                 "shortName": "Noodles",
#                 "id": "4bf58dd8d48988d1d1941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/ramen_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "url": "http://www.okibowldc.com/home/",
#         "contact": {
#             "facebook": "663767173741737",
#             "phone": "2027506703",
#             "facebookUsername": "okibowldc",
#             "formattedPhone": "(202) 750-6703",
#             "facebookName": "OKI Bowl & Sake bar by Sala Thai"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.90568122233118,
#                     "lng": -77.0424391874411,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.90568122233118,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1817 M ST NW",
#                 "Washington, D.C. 20036",
#                 "United States"
#             ],
#             "address": "1817 M ST NW",
#             "postalCode": "20036",
#             "lng": -77.0424391874411
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 821,
#             "tipCount": 17,
#             "usersCount": 450
#         },
#         "id": "54504943498e855981c4abd8",
#         "referralId": "v-1477974037"
#     },
#     {
#         "verified": true,
#         "name": "US Post Office",
#         "url": "https://www.usps.com",
#         "categories": [
#             {
#                 "pluralName": "Post Offices",
#                 "primary": true,
#                 "name": "Post Office",
#                 "shortName": "Post Office",
#                 "id": "4bf58dd8d48988d172941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/building/postoffice_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "venueChains": [
#             {
#                 "id": "556f676fbd6a75a99038d8e8"
#             }
#         ],
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.90551563442811,
#                     "lng": -77.04244136810303,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.90551563442811,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1800 M St NW",
#                 "Washington, D.C. 20033",
#                 "United States"
#             ],
#             "address": "1800 M St NW",
#             "postalCode": "20033",
#             "lng": -77.04244136810303
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 1059,
#             "tipCount": 5,
#             "usersCount": 490
#         },
#         "id": "4b587f5df964a5209f5a28e3",
#         "referralId": "v-1477974037"
#     },
#     {
#         "verified": false,
#         "name": "Mpire",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Strip Clubs",
#                 "primary": true,
#                 "name": "Strip Club",
#                 "shortName": "Strip Club",
#                 "id": "4bf58dd8d48988d1d6941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/stripclub_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "allowMenuUrlEdit": true,
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.90569665239094,
#                     "lng": -77.04255163362976,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.90569665239094,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1819 M St NW",
#                 "Washington, D.C. 20036",
#                 "United States"
#             ],
#             "address": "1819 M St NW",
#             "postalCode": "20036",
#             "lng": -77.04255163362976
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 93,
#             "tipCount": 0,
#             "usersCount": 59
#         },
#         "id": "53eaadf2498ee86ebde8532a",
#         "referralId": "v-1477974037"
#     },
#     {
#         "verified": false,
#         "name": "Bell Wine & Spirits",
#         "allowMenuUrlEdit": true,
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Wine Shops",
#                 "primary": true,
#                 "name": "Wine Shop",
#                 "shortName": "Wine Shop",
#                 "id": "4bf58dd8d48988d119951735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "url": "http://www.bellwineshop.com",
#         "contact": {
#             "phone": "2022234727",
#             "twitter": "BellWineShop",
#             "formattedPhone": "(202) 223-4727"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.905634,
#                     "lng": -77.042549,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.905634,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1821 M St NW (btw 18th St NW & 19th St NW)",
#                 "Washington, D.C. 20036",
#                 "United States"
#             ],
#             "crossStreet": "btw 18th St NW & 19th St NW",
#             "address": "1821 M St NW",
#             "postalCode": "20036",
#             "lng": -77.042549
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 692,
#             "tipCount": 10,
#             "usersCount": 276
#         },
#         "id": "4ba13b57f964a52052a437e3",
#         "referralId": "v-1477974037"
#     }
# ]
# ../data/output/frsq/raw_venues\14000.txt
# ../data/output/frsq/raw_venues\16000.txt
# ../data/output/frsq/raw_venues\18000.txt
# [
#     {
#         "verified": false,
#         "name": "GW Museum Studies Program",
#         "url": "http://museumstudies.columbian.gwu.edu",
#         "categories": [
#             {
#                 "pluralName": "College Arts Buildings",
#                 "primary": true,
#                 "name": "College Arts Building",
#                 "shortName": "Arts",
#                 "id": "4bf58dd8d48988d199941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "venueChains": [],
#         "contact": {
#             "phone": "2029947030",
#             "formattedPhone": "(202) 994-7030"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.898245394963574,
#                     "lng": -77.03064300119158,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.898245394963574,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1310 G Street NW",
#                 "Washington, D.C. 20004",
#                 "United States"
#             ],
#             "address": "1310 G Street NW",
#             "postalCode": "20004",
#             "lng": -77.03064300119158
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 396,
#             "tipCount": 0,
#             "usersCount": 29
#         },
#         "id": "4f0efb2de4b00ae6bcafb7da",
#         "referralId": "v-1477974626"
#     }
# ]
# ../data/output/frsq/raw_venues\2000.txt
# [
#     {
#         "verified": false,
#         "name": "Hair Cuttery",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Health & Beauty Services",
#                 "primary": true,
#                 "name": "Health & Beauty Service",
#                 "shortName": "Health & Beauty",
#                 "id": "54541900498ea6ccd0202697",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "allowMenuUrlEdit": true,
#         "contact": {
#             "phone": "3014901110",
#             "formattedPhone": "(301) 490-1110"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Laurel",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.996490919213855,
#                     "lng": -77.03852037239874,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.996490919213855,
#             "state": "MD",
#             "formattedAddress": [
#                 "14720 Baltimore Ave",
#                 "Laurel, MD 20707",
#                 "United States"
#             ],
#             "address": "14720 Baltimore Ave",
#             "postalCode": "20707",
#             "lng": -77.03852037239874
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 2,
#             "tipCount": 0,
#             "usersCount": 2
#         },
#         "id": "55e4b961498ede7fd9478486",
#         "referralId": "v-1477973060"
#     },
#     {
#         "verified": false,
#         "name": "Cutting Edge Tint",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Automotive Shops",
#                 "primary": true,
#                 "name": "Automotive Shop",
#                 "shortName": "Automotive",
#                 "id": "4bf58dd8d48988d124951735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/automotive_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "allowMenuUrlEdit": true,
#         "contact": {
#             "phone": "3015851353",
#             "formattedPhone": "(301) 585-1353"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Silver Spring",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.996265404934306,
#                     "lng": -77.03843041245528,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.996265404934306,
#             "state": "MD",
#             "formattedAddress": [
#                 "8929 Brookville Rd",
#                 "Silver Spring, MD 20910",
#                 "United States"
#             ],
#             "address": "8929 Brookville Rd",
#             "postalCode": "20910",
#             "lng": -77.03843041245528
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 3,
#             "tipCount": 0,
#             "usersCount": 3
#         },
#         "id": "555e3904498e54e2a66623ae",
#         "referralId": "v-1477973060"
#     },
#     {
#         "verified": false,
#         "name": "Minty's Kitchen",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Indian Restaurants",
#                 "primary": true,
#                 "name": "Indian Restaurant",
#                 "shortName": "Indian",
#                 "id": "4bf58dd8d48988d10f941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/indian_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "allowMenuUrlEdit": true,
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Silver Spring",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.996307373046875,
#                     "lng": -77.03843688964844,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "state": "MD",
#             "formattedAddress": [
#                 "Silver Spring, MD",
#                 "United States"
#             ],
#             "lat": 38.996307373046875,
#             "lng": -77.03843688964844
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 15,
#             "tipCount": 0,
#             "usersCount": 2
#         },
#         "id": "5348c3da11d2903a081ff042",
#         "referralId": "v-1477973060"
#     },
#     {
#         "verified": false,
#         "name": "H's urban garden",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Gardens",
#                 "primary": true,
#                 "name": "Garden",
#                 "shortName": "Garden",
#                 "id": "4bf58dd8d48988d15a941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.99674881832863,
#                     "lng": -77.03796374417422,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "state": "Maryland",
#             "formattedAddress": [
#                 "Maryland",
#                 "United States"
#             ],
#             "lat": 38.99674881832863,
#             "lng": -77.03796374417422
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 13,
#             "tipCount": 0,
#             "usersCount": 1
#         },
#         "id": "53774fcf498eb08ce277eef5",
#         "referralId": "v-1477973060"
#     },
#     {
#         "verified": false,
#         "name": "Summit Hills Apartments 8502",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Residential Buildings (Apartments / Condos)",
#                 "primary": true,
#                 "name": "Residential Building (Apartment / Condo)",
#                 "shortName": "Residential",
#                 "id": "4d954b06a243a5684965b473",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/building/apartment_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Silver Spring",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.99662,
#                     "lng": -77.038022,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.99662,
#             "state": "MD",
#             "formattedAddress": [
#                 "8502 16th St",
#                 "Silver Spring, MD 20910",
#                 "United States"
#             ],
#             "address": "8502 16th St",
#             "postalCode": "20910",
#             "lng": -77.038022
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 1,
#             "tipCount": 0,
#             "usersCount": 1
#         },
#         "id": "5372c922498e81a7c6f642a3",
#         "referralId": "v-1477973060"
#     },
#     {
#         "verified": false,
#         "name": "WMATA Bus Stop #2000188 (J1, J2, J3, J4)",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Bus Lines",
#                 "primary": true,
#                 "name": "Bus Line",
#                 "shortName": "Bus",
#                 "id": "4bf58dd8d48988d12b951735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/busstation_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Silver Spring",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.996431535493166,
#                     "lng": -77.03839667745923,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.996431535493166,
#             "state": "MD",
#             "formattedAddress": [
#                 "East-West Hwy & Summit Hills Apt #1",
#                 "Silver Spring, MD 20910",
#                 "United States"
#             ],
#             "address": "East-West Hwy & Summit Hills Apt #1",
#             "postalCode": "20910",
#             "lng": -77.03839667745923
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 97,
#             "tipCount": 0,
#             "usersCount": 8
#         },
#         "id": "4dc40a551f6ef43b89f1527f",
#         "referralId": "v-1477973060"
#     },
#     {
#         "verified": false,
#         "name": "Ride On Route 1 to Silver Spring",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Bus Lines",
#                 "primary": true,
#                 "name": "Bus Line",
#                 "shortName": "Bus",
#                 "id": "4bf58dd8d48988d12b951735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/busstation_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Silver Spring",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.995240389309004,
#                     "lng": -77.03840229995923,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.995240389309004,
#             "state": "MD",
#             "formattedAddress": [
#                 "Silver Spring, MD 20910",
#                 "United States"
#             ],
#             "postalCode": "20910",
#             "lng": -77.03840229995923
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 1,
#             "tipCount": 0,
#             "usersCount": 1
#         },
#         "id": "50874d85e4b00be3e21bb1e8",
#         "referralId": "v-1477973060"
#     }
# ]
# ../data/output/frsq/raw_venues\20000.txt
# [
#     {
#         "hasMenu": true,
#         "verified": false,
#         "name": "Subway",
#         "venueChains": [
#             {
#                 "id": "556e0bfaa7c82e6b724f552f"
#             }
#         ],
#         "menu": {
#             "url": "https://foursquare.com/v/subway/4c3c94727d00d13af1153950/menu",
#             "mobileUrl": "https://foursquare.com/v/4c3c94727d00d13af1153950/device_menu",
#             "type": "Menu",
#             "anchor": "View Menu",
#             "label": "Menu"
#         },
#         "categories": [
#             {
#                 "pluralName": "Sandwich Places",
#                 "primary": true,
#                 "name": "Sandwich Place",
#                 "shortName": "Sandwiches",
#                 "id": "4bf58dd8d48988d1c5941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/food/deli_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "allowMenuUrlEdit": true,
#         "contact": {
#             "phone": "2023470771",
#             "twitter": "subway",
#             "formattedPhone": "(202) 347-0771"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.89496791734991,
#                     "lng": -77.01906497752104,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.89496791734991,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "501 D St NW",
#                 "Washington, D.C. 20001",
#                 "United States"
#             ],
#             "address": "501 D St NW",
#             "postalCode": "20001",
#             "lng": -77.01906497752104
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 443,
#             "tipCount": 0,
#             "usersCount": 193
#         },
#         "id": "4c3c94727d00d13af1153950",
#         "referralId": "v-1477974822"
#     }
# ]
# ../data/output/frsq/raw_venues\21481.txt
# ../data/output/frsq/raw_venues\4000.txt
# [
#     {
#         "verified": true,
#         "name": "The UPS Store",
#         "allowMenuUrlEdit": true,
#         "venueChains": [
#             {
#                 "id": "556e40c7bd6a82902e2671d1"
#             }
#         ],
#         "storeId": "5801",
#         "categories": [
#             {
#                 "pluralName": "Shipping Stores",
#                 "primary": true,
#                 "name": "Shipping Store",
#                 "shortName": "Shipping Store",
#                 "id": "52f2ab2ebcbc57f1066b8b1f",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/default_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "url": "https://washington-dc-5801.theupsstorelocal.com",
#         "contact": {
#             "facebookName": "The UPS Store 5801",
#             "twitter": "theupsstore",
#             "phone": "2022344877",
#             "facebook": "565085123540590",
#             "formattedPhone": "(202) 234-4877",
#             "facebookUsername": "TheUPSStore5801"
#         },
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.93137261,
#                     "lng": -77.03228487,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.93137261,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1380 Monroe St NW",
#                 "Washington, D.C. 20010",
#                 "United States"
#             ],
#             "address": "1380 Monroe St NW",
#             "postalCode": "20010",
#             "lng": -77.03228487
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 398,
#             "tipCount": 3,
#             "usersCount": 240
#         },
#         "id": "4beae34418389521a2e50acf",
#         "referralId": "v-1477973258"
#     },
#     {
#         "verified": false,
#         "name": "CC Liquors",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Liquor Stores",
#                 "primary": true,
#                 "name": "Liquor Store",
#                 "shortName": "Liquor Store",
#                 "id": "4bf58dd8d48988d186941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "allowMenuUrlEdit": true,
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.931436,
#                     "lng": -77.03264005,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.931436,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "Washington, D.C. 20010",
#                 "United States"
#             ],
#             "postalCode": "20010",
#             "lng": -77.03264005
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 420,
#             "tipCount": 3,
#             "usersCount": 175
#         },
#         "id": "4bb57da8f562ef3b0c112f97",
#         "referralId": "v-1477973258"
#     },
#     {
#         "verified": false,
#         "name": "The Herbert",
#         "venueChains": [],
#         "categories": [
#             {
#                 "pluralName": "Residential Buildings (Apartments / Condos)",
#                 "primary": true,
#                 "name": "Residential Building (Apartment / Condo)",
#                 "shortName": "Residential",
#                 "id": "4d954b06a243a5684965b473",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/building/apartment_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "private": true,
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.931353828108236,
#                     "lng": -77.03262223193924,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.931353828108236,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1511 Park Rd NW",
#                 "Washington, D.C. 20010",
#                 "United States"
#             ],
#             "address": "1511 Park Rd NW",
#             "postalCode": "20010",
#             "lng": -77.03262223193924
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 6,
#             "tipCount": 0,
#             "usersCount": 1
#         },
#         "id": "559d2ee1498eda0fed1ec34d",
#         "referralId": "v-1477973258"
#     },
#     {
#         "verified": false,
#         "name": "Grace DC Church",
#         "venueChains": [],
#         "categories": [],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.93144637764291,
#                     "lng": -77.03283027419957,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.93144637764291,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "3400 14th St NW",
#                 "Washington, D.C. 20010",
#                 "United States"
#             ],
#             "address": "3400 14th St NW",
#             "postalCode": "20010",
#             "lng": -77.03283027419957
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 9,
#             "tipCount": 0,
#             "usersCount": 7
#         },
#         "id": "4e888307be7b2d5c9087ccc3",
#         "referralId": "v-1477973258"
#     }
# ]
# ../data/output/frsq/raw_venues\6000.txt
# ../data/output/frsq/raw_venues\8000.txt
# [
#     {
#         "verified": false,
#         "name": "1731 20th Street Co-Op",
#         "venueChains": [],
#         "categories": [],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "contact": {},
#         "hasPerk": false,
#         "location": {
#             "city": "Washington",
#             "labeledLatLngs": [
#                 {
#                     "lat": 38.913279,
#                     "lng": -77.04459,
#                     "label": "display"
#                 }
#             ],
#             "cc": "US",
#             "country": "United States",
#             "lat": 38.913279,
#             "state": "D.C.",
#             "formattedAddress": [
#                 "1731 20th St NW",
#                 "Washington, D.C. 20009",
#                 "United States"
#             ],
#             "address": "1731 20th St NW",
#             "postalCode": "20009",
#             "lng": -77.04459
#         },
#         "beenHere": {
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "stats": {
#             "checkinsCount": 9,
#             "tipCount": 0,
#             "usersCount": 4
#         },
#         "id": "4c81d1dedc018cfa4bebc96c",
#         "referralId": "v-1477973648"
#     }
# ]
# 18

# %%
df_venues = json_normalize(all_venues)

# %%
import shapely.geometry as shpgeo

# %%
df_venues['categories.name'] = df_venues.categories.apply(lambda x: x[0]['name'] if x else '')
df_venues['categories.id'] = df_venues.categories.apply(lambda x: x[0]['id'] if x else '')
df_venues['geometry'] = df_venues.apply(lambda x: shpgeo.Point(x['location.lng'], x['location.lat']), axis=1)

# %%
df_venues['location.isFuzzed'].value_counts()
# Out:
# True    2
# dtype: int64

# %%
print df_venues['location.labeledLatLngs'].apply(lambda x: x[0]['label'] if type(x)!=float else 0).value_counts()
df_venues.apply(lambda x: (x['location.labeledLatLngs'][0]['lng']/x['location.lng'] )
                            if type(x['location.labeledLatLngs'])!=float else 0, axis=1).value_counts()
# Out:
# display    42793
# 0            211
# dtype: int64
# 1    42793
# 0      211
# dtype: int64

# %%
columns = ['id', 'geometry', 'name', 'stats.checkinsCount', 'stats.tipCount', 'stats.usersCount','categories.name']
df_no_dup = df_venues[columns].drop_duplicates('id').copy()
df_no_dup.columns = ['id', 'geometry', 'name', 'checkins', 'tips', 'users','category']
df_no_dup.shape
# Out:
# (34731, 7)

# %%
dc_poly_path = '../data/dc_polygon.geojson'
dc_poly_gpdf = gp.read_file(dc_poly_path)
dc_poly = dc_poly_gpdf.geometry.values[0]

# %%
print df_no_dup.geometry.apply(lambda x: x.intersects(dc_poly)).value_counts()
df_no_dup_in_dc = df_no_dup[df_no_dup.geometry.apply(lambda x: x.intersects(dc_poly))].copy()
# Out:
# True     34060
# False      671
# dtype: int64

# %%
import geopandas as gp
with open(EXTRACTED_VENUES, 'w') as f:
    f.write(gp.GeoDataFrame(df_no_dup_in_dc).to_json())
