# %%
import sys, os
sys.path.insert(0, os.path.abspath('../'))
import utils.osm_helper
reload(utils.osm_helper)
from utils.osm_helper import *
import geopandas as gp
# %matplotlib inline
from osmread import parse_file, Node, Way, Relation

# %%
DCOSM_DATA_PATH = '../data/washingtonDC.osm'
OUTPUT_DIR = '../data/output/'

# %%
OSM_DATA = osm_container(DCOSM_DATA_PATH)
print OSM_DATA.data_size()
# Out:
# begin reading osm 2016-11-08 16:09:03.079000
# finish reading osm 2016-11-08 16:10:14.731000
# ["len of <class 'osmread.elements.Relation'> = 3427", "len of <class 'osmread.elements.Node'> = 2546260", "len of <class 'osmread.elements.Way'> = 306332"]

# %%
def get_area_ways(osm_data):
    polys = []
    for way in osm_data.osm_objs[Way]:
        ln = way2line(osm_data, way)
        if ln.is_ring and len(ln.coords)>=3:
            poly=shpgeo.Polygon(ln)
            polys.append((way.id,poly))
    gpdf = gp.GeoDataFrame(polys, columns=['wayid', 'geometry'])
    gpdf.crs = {'init':'epsg:4326'}
    gpdf = gpdf.to_crs(epsg=3559)
    gpdf['area'] = gpdf.geometry.apply(lambda x:x.area)
    return gpdf

gpdf_area = get_area_ways(OSM_DATA)
gpdf_area.shape
# Out:
# (236256, 3)

# %%
gpdf_area[gpdf_area.wayid==440070008]
# Out:
#             wayid                                           geometry  \
# 234411  440070008  POLYGON ((397703.9664811385 128994.4518940037,...
#
#                   area
# 234411  2478560.520169

# %%
gpdf_area.sort('area',ascending=False)
# Out:
#             wayid                                           geometry  \
# 234467  440165276  POLYGON ((397839.6066623423 129512.2712607725,...
# 124298  221896965  POLYGON ((395984.9200541574 122403.3771531997,...
# 109140  116893146  POLYGON ((384598.9684163657 150541.3917227949,...
# 100466   91278574  POLYGON ((409565.5745513114 146728.5611949514,...
# 111249  137952788  POLYGON ((391255.1800687139 138418.698342034, ...
# 123657  220515922  POLYGON ((392138.0621015504 145815.2265632857,...
# 134801  243497073  POLYGON ((408271.4277737296 146429.084568467, ...
# 124297  221896964  POLYGON ((396006.1943844497 120608.7722200295,...
# 25191    56001530  POLYGON ((396284.3207673127 132842.9149177316,...
# 109014  111781641  POLYGON ((393036.3260476024 150921.3911488999,...
# 215684  315105873  POLYGON ((397763.0668359299 125220.506049624, ...
# 1220     41654965  POLYGON ((393893.9485836452 135541.1479585084,...
# 234411  440070008  POLYGON ((397703.9664811385 128994.4518940037,...
# 9055     51858784  POLYGON ((403646.9305375757 137731.0312776858,...
# 109099  112644667  POLYGON ((388079.6673352683 146195.5482588496,...
# 221530  331300608  POLYGON ((401282.4297168346 130849.7578327959,...
# 135218  243871618  POLYGON ((405580.6408115789 123269.4032367561,...
# 139240  266960875  POLYGON ((411259.6182439348 122961.539993104, ...
# 109103  112648293  POLYGON ((386634.3207514809 147822.4695470302,...
# 110239  120905695  POLYGON ((403921.9536906658 138247.5840924031,...
# 221448  330719057  POLYGON ((397882.7149739314 140903.6069405045,...
# 221425  330406611  POLYGON ((390767.9519187961 140914.9578562357,...
# 221532  331305751  POLYGON ((399668.1762443538 127935.3675330907,...
# 109098  112644585  POLYGON ((387418.9777827357 144997.8653972911,...
# 139270  267600353  POLYGON ((406606.5996315617 123821.0137840917,...
# 135187  243692108  POLYGON ((403943.5635084694 125662.0986293056,...
# 909      38087551  POLYGON ((382174.6215627443 143510.3793207891,...
# 221439  330586385  POLYGON ((399227.850894446 139498.7249093914, ...
# 109080  112599254  POLYGON ((388052.7105992101 144484.3292400438,...
# 1435     41964935  POLYGON ((404904.2788918167 133673.3862480173,...
# ...           ...                                                ...
# 233103  427085609  POLYGON ((395119.6515142595 136470.1775184416,...
# 233149  427085655  POLYGON ((395220.4414208311 136478.9744810138,...
# 233102  427085608  POLYGON ((395220.4729660198 136488.1215179291,...
# 233146  427085652  POLYGON ((395220.5045111463 136497.2685549804,...
# 233154  427085660  POLYGON ((395119.7551737954 136497.6186226502,...
# 233150  427085656  POLYGON ((395119.7868352322 136506.7656594366,...
# 233129  427085635  POLYGON ((395119.8184966102 136515.912696359, ...
# 233151  427085657  POLYGON ((395220.6078209698 136524.7096617, 39...
# 233155  427085661  POLYGON ((395119.8501647689 136525.0708342063,...
# 233099  427085604  POLYGON ((395220.6393658472 136533.8566992894,...
# 233092  427085597  POLYGON ((395119.8818260256 136534.2178713949,...
# 233110  427085616  POLYGON ((395220.6709173641 136543.0148378038,...
# 233138  427085644  POLYGON ((395202.3813678015 136552.2173571441,...
# 233113  427085619  POLYGON ((395174.908415056 136552.3228551445, ...
# 233101  427085607  POLYGON ((395156.5873213643 136552.3784425732,...
# 233091  427085595  POLYGON ((395138.2662347213 136552.4451731813,...
# 7686     48112150  POLYGON ((398266.4407252802 128295.5110695115,...
# 50266    67120479  POLYGON ((395313.8112891613 144947.1653036989,...
# 52307    67136905  POLYGON ((398093.9626560037 126922.556001969, ...
# 18160    55328623  POLYGON ((401957.2401752978 131201.1108556247,...
# 138884  257920179  POLYGON ((396735.9990505619 136646.3929631979,...
# 138883  257920178  POLYGON ((396738.627466455 136646.3696786722, ...
# 138886  257920181  POLYGON ((396730.7248740633 136646.4506428244,...
# 138885  257920180  POLYGON ((396733.3619600142 136646.4162521734,...
# 52850    67140891  POLYGON ((404591.8783989524 135805.1009915383,...
# 18608    55329470  POLYGON ((401914.9130078565 131957.0255919852,...
# 61707    67384966  POLYGON ((401161.2071593345 129492.3137922096,...
# 117287  205199571  POLYGON ((395824.4700797675 126460.2635144374,...
# 37494    66790052  POLYGON ((395956.9441894687 138599.9964698772,...
# 235126  444024204  POLYGON ((397007.3972759779 135964.1865045273,...
#
#                    area
# 234467  11475921.495604
# 124298   6086803.168194
# 109140   5000654.553680
# 100466   4776472.717058
# 111249   4282808.636221
# 123657   4241646.897114
# 134801   3339311.419129
# 124297   3150745.397155
# 25191    2924501.851116
# 109014   2718318.282386
# 215684   2706166.045474
# 1220     2551964.962615
# 234411   2478560.520169
# 9055     2392014.026558
# 109099   2305549.922812
# 221530   2046524.885425
# 135218   2013490.064539
# 139240   1857186.136256
# 109103   1828680.346041
# 110239   1828545.614826
# 221448   1791427.438110
# 221425   1636930.022418
# 221532   1602059.321419
# 109098   1601695.535142
# 139270   1593984.496786
# 135187   1568057.509132
# 909      1533866.852612
# 221439   1518577.621796
# 109080   1513599.727870
# 1435     1492764.449220
# ...                 ...
# 233103         0.469163
# 233149         0.469163
# 233102         0.469162
# 233146         0.469162
# 233154         0.469162
# 233150         0.469161
# 233129         0.469161
# 233151         0.469160
# 233155         0.469160
# 233099         0.469160
# 233092         0.469160
# 233110         0.469159
# 233138         0.469158
# 233113         0.469158
# 233101         0.469158
# 233091         0.469158
# 7686           0.422311
# 50266          0.404024
# 52307          0.277958
# 18160          0.268270
# 138884         0.257158
# 138883         0.254750
# 138886         0.254654
# 138885         0.253980
# 52850          0.243846
# 18608          0.237508
# 61707          0.215365
# 117287         0.211927
# 37494          0.120292
# 235126         0.000000
#
# [236256 rows x 3 columns]

# %%
def get_rltn_area(osm_data):
    result = []
    for r in osm_data.osm_objs[Relation]:
        merge_shpcltn, status = rltn2mergedCltn(osm_data, r)
        if status!='error':
            for a in merge_shpcltn.geometry.values:
                result.append((r.id,a))
            
    return result
# get_rltn_area(OSM_DATA)
all_merge_shp = get_rltn_area(OSM_DATA)
# Out:
# 50372 relation's member out of osm bound, no need to consider 113295049L
# 62152 relation's member out of osm bound, no need to consider 215634L
# 112245 relation's member out of osm bound, no need to consider 2297232L
# 133366 relation's member out of osm bound, no need to consider 34313742L
# 133386 relation's member out of osm bound, no need to consider 34314601L
# 133393 relation's member out of osm bound, no need to consider 34314461L
# 133482 relation's member out of osm bound, no need to consider 34317348L
# 133492 relation's member out of osm bound, no need to consider 34317467L
# 133501 relation's member out of osm bound, no need to consider 34317475L
# 133513 relation's member out of osm bound, no need to consider 34303757L
# 133514 relation's member out of osm bound, no need to consider 34314019L
# 133518 relation's member out of osm bound, no need to consider 404669425L
# 133524 relation's member out of osm bound, no need to consider 34317735L
# 133564 relation's member out of osm bound, no need to consider 34313744L
# 133605 relation's member out of osm bound, no need to consider 87611811L
# 133612 relation's member out of osm bound, no need to consider 34317594L
# 133737 relation's member out of osm bound, no need to consider 208145253L
# 148838 relation's member out of osm bound, no need to consider 376956460L
# 162112 relation's member out of osm bound, no need to consider 436652130L
# 162525 relation's member out of osm bound, no need to consider 20376328L
# 176453 relation's member out of osm bound, no need to consider 237173208L
# 192836 relation's member out of osm bound, no need to consider 243347089L
# 206696 relation's member out of osm bound, no need to consider 39233351L
# 206697 relation's member out of osm bound, no need to consider 39233415L
# 206704 relation's member out of osm bound, no need to consider 39233772L
# 206734 relation's member out of osm bound, no need to consider 39234839L
# 206737 relation's member out of osm bound, no need to consider 171846563L
# 206739 relation's member out of osm bound, no need to consider 39236191L
# 206746 relation's member out of osm bound, no need to consider 39233183L
# 206826 relation's member out of osm bound, no need to consider 143784412L
# 206827 relation's member out of osm bound, no need to consider 39239319L
# 206828 relation's member out of osm bound, no need to consider 359782142L
# 206832 relation's member out of osm bound, no need to consider 39236502L
# 206834 relation's member out of osm bound, no need to consider 147028541L
# 224042 relation's member out of osm bound, no need to consider 292839118L
# 269474 relation's member out of osm bound, no need to consider 409370L
# 270832 relation's member out of osm bound, no need to consider 359866069L
# 325656 relation's member out of osm bound, no need to consider 44414917L
# 331325 relation's member out of osm bound, no need to consider 317707L
# 396363 relation's member out of osm bound, no need to consider 37811898L
# 396364 relation's member out of osm bound, no need to consider 20270982L
# 400284 relation's member out of osm bound, no need to consider 43679544L
# 406327 relation's member out of osm bound, no need to consider 20368281L
# 916095 relation's member out of osm bound, no need to consider 169913724L
# 936412 relation's member out of osm bound, no need to consider 93660576L
# 936970 relation's member out of osm bound, no need to consider 92341552L
# 945043 relation's member out of osm bound, no need to consider 148657449L
# 968697 relation's member out of osm bound, no need to consider 448213898L
# 1060711 relation's member out of osm bound, no need to consider 37960049L
# 1084928 relation's member out of osm bound, no need to consider 255478539L
# 1086322 relation's member out of osm bound, no need to consider 435225558L
# 1161688 relation's member out of osm bound, no need to consider 232594467L
# 1168751 relation's member out of osm bound, no need to consider 26933680L
# 1269021 relation's member out of osm bound, no need to consider 108058098L
# 1314032 relation's member out of osm bound, no need to consider 50875181L
# 1314034 relation's member out of osm bound, no need to consider 50874702L
# 1319442 relation's member out of osm bound, no need to consider 229673008L
# 1320731 relation's member out of osm bound, no need to consider 49248691L
# 1320733 relation's member out of osm bound, no need to consider 17679823L
# 1346204 relation's member out of osm bound, no need to consider 106199744L
# 1346540 relation's member out of osm bound, no need to consider 37811887L
# 1355085 relation's member out of osm bound, no need to consider 37811898L
# 1359387 relation's member out of osm bound, no need to consider 188552163L
# 1392951 relation's member out of osm bound, no need to consider 137852562L
# 1403277 relation's member out of osm bound, no need to consider 1129957203L
# 1403278 relation's member out of osm bound, no need to consider 1129957394L
# 1403279 relation's member out of osm bound, no need to consider 1129957203L
# 1405414 relation's member out of osm bound, no need to consider 1133722108L
# 1405415 relation's member out of osm bound, no need to consider 1131791923L
# 1405417 relation's member out of osm bound, no need to consider 1131791923L
# 1405499 relation's member out of osm bound, no need to consider 85200623L
# 1405856 relation's member out of osm bound, no need to consider 1131791923L
# 1405857 relation's member out of osm bound, no need to consider 1134236492L
# 1416189 relation's member out of osm bound, no need to consider 98797668L
# 1416190 relation's member out of osm bound, no need to consider 98797655L
# 1416191 relation's member out of osm bound, no need to consider 98797819L
# 1416192 relation's member out of osm bound, no need to consider 98797650L
# 1441247 relation's member out of osm bound, no need to consider 111535238L
# 1478081 relation's member out of osm bound, no need to consider 136343965L
# 1541203 relation's member out of osm bound, no need to consider 8802275L
# 1541302 relation's member out of osm bound, no need to consider 319329763L
# 1541423 relation's member out of osm bound, no need to consider 8812481L
# 1569968 relation's member out of osm bound, no need to consider 1270463249L
# 1571428 relation's member out of osm bound, no need to consider 338870369L
# 1574111 relation's member out of osm bound, no need to consider 50735247L
# 1590286 relation's member out of osm bound, no need to consider 895371274L
# 1600955 relation's member out of osm bound, no need to consider 26528767L
# 1600965 relation's member out of osm bound, no need to consider 26527894L
# 1600974 relation's member out of osm bound, no need to consider 244626211L
# 1600976 relation's member out of osm bound, no need to consider 5968794L
# 1601108 relation's member out of osm bound, no need to consider 11506733L
# 1601110 relation's member out of osm bound, no need to consider 6131085L
# 1601119 relation's member out of osm bound, no need to consider 6139142L
# 1601121 relation's member out of osm bound, no need to consider 114637604L
# 1601122 relation's member out of osm bound, no need to consider 51706614L
# 1601128 relation's member out of osm bound, no need to consider 50879360L
# 1601129 relation's member out of osm bound, no need to consider 31898265L
# 1623950 relation's member out of osm bound, no need to consider 38086237L
# 1634310 relation's member out of osm bound, no need to consider 118635939L
# 1642655 relation's member out of osm bound, no need to consider 8801940L
# 1659168 relation's member out of osm bound, no need to consider 47026267L
# 1685924 relation's member out of osm bound, no need to consider 123069065L
# 1685926 relation's member out of osm bound, no need to consider 26467528L
# 1689687 relation's member out of osm bound, no need to consider 299021473L
# 1772402 relation's member out of osm bound, no need to consider 201673062L
# 1774795 relation's member out of osm bound, no need to consider 1225400L
# 1778673 relation's member out of osm bound, no need to consider 132577589L
# 1779889 relation's member out of osm bound, no need to consider 20337425L
# 1809808 relation's member out of osm bound, no need to consider 13486032L
# 1897938 relation's member out of osm bound, no need to consider 895371274L
# 1900976 relation's member out of osm bound, no need to consider 101537749L
# 1933179 relation's member out of osm bound, no need to consider 142815348L
# 1933181 relation's member out of osm bound, no need to consider 131823797L
# 1933187 relation's member out of osm bound, no need to consider 142815351L
# 1948101 relation's member out of osm bound, no need to consider 143794277L
# 1983421 relation's member out of osm bound, no need to consider 144052164L
# 2063644 relation's member out of osm bound, no need to consider 432462148L
# 2067020 relation's member out of osm bound, no need to consider 229464625L
# 2067021 relation's member out of osm bound, no need to consider 153130300L
# 2067024 relation's member out of osm bound, no need to consider 153130387L
# 2134489 relation's member out of osm bound, no need to consider 203193602L
# 2193912 relation's member out of osm bound, no need to consider 431979433L
# 2259816 relation's member out of osm bound, no need to consider 6128292L
# 2259837 relation's member out of osm bound, no need to consider 72442465L
# 2302686 relation's member out of osm bound, no need to consider 53190696L
# 2302696 relation's member out of osm bound, no need to consider 171578142L
# 2309298 relation's member out of osm bound, no need to consider 60816123L
# 2309304 relation's member out of osm bound, no need to consider 51370623L
# 2348341 relation's member out of osm bound, no need to consider 312005328L
# 2531779 relation's member out of osm bound, no need to consider 187957287L
# 2532740 relation's member out of osm bound, no need to consider 137852562L
# 2637000 relation's member out of osm bound, no need to consider 87435764L
# 2637001 relation's member out of osm bound, no need to consider 2636998L
# 2648181 relation's member out of osm bound, no need to consider 308160624L
# 2709610 relation's member out of osm bound, no need to consider 43679544L
# 2793832 relation's member out of osm bound, no need to consider 207779323L
# 2794554 relation's member out of osm bound, no need to consider 72442465L
# 2807121 relation's member out of osm bound, no need to consider 208516283L
# 2964856 relation's member out of osm bound, no need to consider 143784382L
# 3022887 relation's member out of osm bound, no need to consider 1770787L
# 3031441 relation's member out of osm bound, no need to consider 294559919L
# 3223900 relation's member out of osm bound, no need to consider 239059622L
# 3307735 relation's member out of osm bound, no need to consider 26719802L
# 3322741 relation's member out of osm bound, no need to consider 137852562L
# 3517701 relation's member out of osm bound, no need to consider 261971092L
# 3697467 relation's member out of osm bound, no need to consider 277937385L
# 3733658 relation's member out of osm bound, no need to consider 315396161L
# 3733659 relation's member out of osm bound, no need to consider 171991351L
# 3748877 relation's member out of osm bound, no need to consider 232847644L
# 3757399 relation's member out of osm bound, no need to consider 171723235L
# 4237277 relation's member out of osm bound, no need to consider 437408518L
# 4237294 relation's member out of osm bound, no need to consider 315105769L
# 4242467 relation's member out of osm bound, no need to consider 315356081L
# 4460896 relation's member out of osm bound, no need to consider 73917984L
# 4520382 relation's member out of osm bound, no need to consider 130576275L
# 4799100 relation's member out of osm bound, no need to consider 96744555L
# 4799101 relation's member out of osm bound, no need to consider 96744555L
# 4799475 relation's member out of osm bound, no need to consider 848230522L
# 4799476 relation's member out of osm bound, no need to consider 98797650L
# 4799477 relation's member out of osm bound, no need to consider 98797650L
# 5497199 relation's member out of osm bound, no need to consider 231269487L
# 5575328 relation's member out of osm bound, no need to consider 374791136L
# 5575382 relation's member out of osm bound, no need to consider 374790880L
# 6096736 relation's member out of osm bound, no need to consider 407044038L
# 6131324 relation's member out of osm bound, no need to consider 6135950L
# 6131325 relation's member out of osm bound, no need to consider 6137781L
# 6290688 relation's member out of osm bound, no need to consider 400363034L
# 6429928 relation's member out of osm bound, no need to consider 335310303L
# 6452460 relation's member out of osm bound, no need to consider 312680185L
# 6478274 relation's member out of osm bound, no need to consider 436339936L
# 6478276 relation's member out of osm bound, no need to consider 50733620L
# 6649229 relation's member out of osm bound, no need to consider 23891857L

# %%
gpdf_rltn = gp.GeoDataFrame(all_merge_shp, columns=['rid','geometry'])
gpdf_rltn.crs = {'init':'epsg:4326'}
gpdf_rltn = gpdf_rltn.to_crs(epsg=3559)

# %%
gpdf_rltn['area']=gpdf_rltn.geometry.apply(lambda x: x.area)

# %%
merge_shpcltn, status = rltn2mergedCltn(OSM_DATA,OSM_DATA.get_osm_relation_by_id(4644977))
for a in merge_shpcltn.values:
    print a
print merge_shpcltn.geometry.values
# Out:
# [<shapely.geometry.linestring.LineString object at 0x00000000CBD24160>]
# [<shapely.geometry.polygon.Polygon object at 0x00000000D0260EB8>]
# [<shapely.geometry.linestring.LineString object at 0x00000000CBD24160>
#  <shapely.geometry.polygon.Polygon object at 0x00000000D0260EB8>]

# %%
gpdf_rltn[gpdf_rltn.rid==4644977].plot()

# %%
gpdf_rltn_area = gpdf_rltn.groupby('rid').agg(sum).sort('area',ascending=False)

# %%
tags_to_exclude = set(['waterway', 'admin_level', 'boundary', 'place'])
rs = []
for r in OSM_DATA.osm_objs[Relation]:
    if len(set(r.tags.keys())&tags_to_exclude)>0:
        rs.append(r)
rids = [(r.id, r.tags.get('waterway',''),r.tags.get('admin_level',''),r.tags.get('boundary',''),r.tags.get('place',''),) for r in rs]

# %%
gpdf_rltn_area.reset_index().merge(pd.DataFrame(rids,columns=['rid','waterway', 'admin_level', 'boundary','place']))
# Out:
#          rid          area   waterway admin_level        boundary  \
# 0    5396194  1.771371e+08                      8  administrative
# 1     162069  1.771371e+08                      4  administrative
# 2     206845  6.736753e+07                      8  administrative
# 3     962190  6.736753e+07                      6  administrative
# 4     962189  4.086565e+07                      6  administrative
# 5     206637  4.010932e+07                      8  administrative
# 6     133559  2.363126e+07                      8  administrative
# 7     133515  1.907209e+07                      8  administrative
# 8     133557  1.446115e+07                      8  administrative
# 9     206733  1.192815e+07                      8  administrative
# 10    133396  1.063939e+07                      8  administrative
# 11    133523  1.039711e+07                      8  administrative
# 12    133379  9.382490e+06                      8  administrative
# 13    133522  8.193647e+06                      8  administrative
# 14    206690  7.584473e+06                      8  administrative
# 15    133382  6.983768e+06                      8  administrative
# 16    206702  6.892422e+06                      8  administrative
# 17   6612210  6.704736e+06                     11  administrative
# 18    133787  6.503677e+06                      8  administrative
# 19    133560  6.443084e+06                      8  administrative
# 20   6612211  5.637416e+06                     11  administrative
# 21    133257  5.438052e+06                      8  administrative
# 22    133558  5.331196e+06                      8  administrative
# 23    206701  5.300141e+06                      8  administrative
# 24    206642  5.183295e+06                      8  administrative
# 25    962188  5.089149e+06                      6  administrative
# 26    133483  5.044798e+06                      8  administrative
# 27   6603461  4.737332e+06                     11  administrative
# 28    133520  4.274008e+06                      8  administrative
# 29    133364  4.249332e+06                      8  administrative
# ..       ...           ...        ...         ...             ...
# 201  4646938  1.991535e+05                           neighborhood
# 202  4644977  1.712828e+05                                 suburb
# 203  4648081  1.696740e+05                           neighborhood
# 204  3642557  1.642882e+05  riverbank
# 205   133259  1.512786e+05                      8  administrative
# 206  4647962  1.265080e+05                           neighborhood
# 207  4237295  1.170762e+05                         protected_area
# 208  1895644  1.020934e+05  riverbank
# 209  5375957  7.425035e+04                      8  administrative
# 210  4648060  7.363933e+04                           neighborhood
# 211  5375958  6.625775e+04                      8  administrative
# 212  4636508  5.065286e+04                           neighborhood
# 213  4636922  3.202962e+04                           neighborhood
# 214  5575340  2.813830e+04                         protected_area
# 215  5575406  2.628379e+04                         protected_area
# 216  5575318  1.982451e+04                         protected_area
# 217  5575321  1.205035e+04                         protected_area
# 218  5575322  7.241155e+03                         protected_area
# 219  5575424  2.775707e+03                         protected_area
# 220  5575375  2.264132e+03                         protected_area
# 221  5656224  2.195045e+03
# 222  2636997  0.000000e+00      river
# 223  4633767  0.000000e+00                           neighborhood
# 224  4645121  0.000000e+00                           neighborhood
# 225  4642217  0.000000e+00                           neighborhood
# 226  4639640  0.000000e+00                           neighborhood
# 227  4638652  0.000000e+00                           neighborhood
# 228  4638565  0.000000e+00                           neighborhood
# 229  4626888  0.000000e+00                           neighborhood
# 230  4626529  0.000000e+00                                 suburb
#
#              place
# 0
# 1
# 2         locality
# 3
# 4
# 5             city
# 6         locality
# 7         locality
# 8         locality
# 9         locality
# 10        locality
# 11        locality
# 12        locality
# 13        locality
# 14        locality
# 15            city
# 16        locality
# 17
# 18        locality
# 19        locality
# 20
# 21            city
# 22        locality
# 23        locality
# 24            city
# 25
# 26        locality
# 27
# 28        locality
# 29            town
# ..             ...
# 201  neighbourhood
# 202         suburb
# 203  neighbourhood
# 204
# 205        village
# 206  neighbourhood
# 207
# 208
# 209
# 210  neighbourhood
# 211
# 212  neighbourhood
# 213  neighbourhood
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221         island
# 222
# 223  neighbourhood
# 224  neighbourhood
# 225  neighbourhood
# 226  neighbourhood
# 227  neighbourhood
# 228  neighbourhood
# 229  neighbourhood
# 230         suburb
#
# [231 rows x 6 columns]

# %%
def filter_obj(obj, tag, value='*'):
    if not tag in obj.tags:
        return False
    if value=='*':
        return True
    return obj.tags[tag]==value

def filters(obj, have_one, donthave):
    for tag, value in donthave:
        if filter_obj(obj,tag, value):
            return False
    
    b_have_one = False
    for tag, value in have_one:
        b_have_one = b_have_one or filter_obj(obj, tag,value)
    return b_have_one

# %%
#  ('route','*') should be interseting, especially route=bicycle
#  ('waterway','*') should be interesting, but need to keep track in the stage of merging node, ways and relations
have_one = [('boundary','*'),
            ('place','*'), 
            ('landuse', '*')
           ]
donthave = [('leisure','*'), ('amenity','*'), ('boundary','national_park'), ('boundary', 'protected_area' )]
attr =[x[0] for x in have_one]

def filter_osm_data(osm_data,osmtype,have_one, donthave,attr):
    objs = []
    for o in osm_data.osm_objs[osmtype]:
        if filters(o, have_one, donthave):
            objs.append(o)
    objs = [[o.id]+[o.tags.get(k,'') for k in attr] for o in objs]
    return objs
rids = filter_osm_data(OSM_DATA,Relation,have_one, donthave,attr)
df = gpdf_rltn_area.reset_index().merge(pd.DataFrame(rids,columns=['rid']+attr))
df
# Out:
#          rid          area        boundary          place       landuse
# 0    5396194  1.771371e+08  administrative
# 1     162069  1.771371e+08  administrative
# 2     206845  6.736753e+07  administrative       locality
# 3     962190  6.736753e+07  administrative
# 4     962189  4.086565e+07  administrative
# 5     206637  4.010932e+07  administrative           city
# 6     133559  2.363126e+07  administrative       locality
# 7     133515  1.907209e+07  administrative       locality
# 8     133557  1.446115e+07  administrative       locality
# 9     206733  1.192815e+07  administrative       locality
# 10    133396  1.063939e+07  administrative       locality
# 11    133523  1.039711e+07  administrative       locality
# 12    133379  9.382490e+06  administrative       locality
# 13    133522  8.193647e+06  administrative       locality
# 14    206690  7.584473e+06  administrative       locality
# 15    133382  6.983768e+06  administrative           city
# 16    206702  6.892422e+06  administrative       locality
# 17   6612210  6.704736e+06  administrative
# 18    133787  6.503677e+06  administrative       locality
# 19    133560  6.443084e+06  administrative       locality
# 20   6612211  5.637416e+06  administrative
# 21    133257  5.438052e+06  administrative           city
# 22    133558  5.331196e+06  administrative       locality
# 23    206701  5.300141e+06  administrative       locality
# 24    206642  5.183295e+06  administrative           city
# 25    962188  5.089149e+06  administrative
# 26    133483  5.044798e+06  administrative       locality
# 27   6603461  4.737332e+06  administrative
# 28    133520  4.274008e+06  administrative       locality
# 29    133364  4.249332e+06  administrative           town
# ..       ...           ...             ...            ...           ...
# 208  3478741  1.004426e+05                                  residential
# 209  3045363  8.586878e+04                                  residential
# 210  5375957  7.425035e+04  administrative
# 211  4648060  7.363933e+04    neighborhood  neighbourhood
# 212  1067080  7.210370e+04                                  residential
# 213  5375958  6.625775e+04  administrative
# 214  4636508  5.065286e+04    neighborhood  neighbourhood
# 215  3004126  3.550447e+04                                       retail
# 216  4636922  3.202962e+04    neighborhood  neighbourhood
# 217  4049362  3.180823e+04                                        grass
# 218  4603196  2.924377e+04                                  residential
# 219  4630855  1.070960e+04                                       retail
# 220  6594202  1.037642e+04                                        grass
# 221  3211113  8.675586e+03                                        grass
# 222  2812765  4.180753e+03                                   allotments
# 223  3158768  3.273501e+03                                        grass
# 224  5537049  2.231420e+03                                        grass
# 225  5656224  2.195045e+03                         island
# 226  6654870  1.634185e+03                                  residential
# 227  3305223  1.304240e+03                                        grass
# 228  4618040  5.696487e+02                                   commercial
# 229   554411  5.230391e+02                                 construction
# 230  4633767  0.000000e+00    neighborhood  neighbourhood
# 231  4645121  0.000000e+00    neighborhood  neighbourhood
# 232  4642217  0.000000e+00    neighborhood  neighbourhood
# 233  4639640  0.000000e+00    neighborhood  neighbourhood
# 234  4638652  0.000000e+00    neighborhood  neighbourhood
# 235  4638565  0.000000e+00    neighborhood  neighbourhood
# 236  4626888  0.000000e+00    neighborhood  neighbourhood
# 237  4626529  0.000000e+00          suburb         suburb
#
# [238 rows x 5 columns]

# %%
print have_one, donthave
ways = filter_osm_data(OSM_DATA,Way,have_one, donthave,attr)
df2 = gpdf_area.reset_index().merge(pd.DataFrame(ways,columns=['wayid']+attr))
df2
# Out:
# [('boundary', '*'), ('place', '*'), ('landuse', '*')] [('leisure', '*'), ('amenity', '*'), ('boundary', 'national_park'), ('boundary', 'protected_area')]
#        index      wayid                                           geometry  \
# 0        325   21692787  POLYGON ((396027.479465716 122531.1233227227, ...
# 1        326   21693235  POLYGON ((396010.7667058067 122683.4093965452,...
# 2        327   21694219  POLYGON ((385319.0498135864 144719.2083280867,...
# 3        328   21694421  POLYGON ((388526.6368517831 143165.6459854018,...
# 4        329   21694848  POLYGON ((387267.6768946547 144486.0532801318,...
# 5        576   24942401  POLYGON ((403835.1347485789 146374.202893728, ...
# 6        785   27308469  POLYGON ((394845.6461636972 125912.0576510821,...
# 7        800   27309879  POLYGON ((392440.2493420034 126739.5289357582,...
# 8        804   27311168  POLYGON ((390181.2846102583 127128.0072587237,...
# 9        831   28295063  POLYGON ((389096.9594195494 141402.5919210345,...
# 10       837   28317055  POLYGON ((391118.0187977058 134851.5522221698,...
# 11       839   28317128  POLYGON ((392029.4014380562 135434.2725764415,...
# 12       852   29221752  POLYGON ((403101.5125457282 127407.6097045576,...
# 13       871   31487164  POLYGON ((388221.2142948219 127504.3915478801,...
# 14       893   34320815  POLYGON ((393293.2814848092 148530.6893772937,...
# 15       922   38093436  POLYGON ((391145.6327761114 134087.4334047345,...
# 16       936   38134372  POLYGON ((396772.8678137264 147851.9851480268,...
# 17       937   38155589  POLYGON ((396999.7766375577 148004.8123050906,...
# 18       938   38155590  POLYGON ((396891.996370286 147926.447447015, 3...
# 19       939   38155591  POLYGON ((396710.2934802772 148129.4475728369,...
# 20       940   38155593  POLYGON ((396758.9324934952 148069.3709680912,...
# 21       941   38155594  POLYGON ((396683.2289145509 147912.9446115964,...
# 22       942   38155595  POLYGON ((396891.2891630522 147912.3050301566,...
# 23       943   38155596  POLYGON ((396689.3544811042 148371.2143997776,...
# 24       944   38155597  POLYGON ((396778.5605975429 148259.8786796639,...
# 25       945   38155598  POLYGON ((396651.5411478419 148197.0552530636,...
# 26       946   38155599  POLYGON ((396536.7160580499 148510.3534531953,...
# 27       947   38155600  POLYGON ((396538.5252921381 148369.4362178533,...
# 28       948   38155601  POLYGON ((396575.1427086198 148538.3335116424,...
# 29       949   38155603  POLYGON ((396797.905019564 148458.0352312618, ...
# ...      ...        ...                                                ...
# 2756  234506  440168624  POLYGON ((398323.8179400277 127817.9152880696,...
# 2757  234507  440168625  POLYGON ((398334.4807224517 127975.6977030991,...
# 2758  234508  440168626  POLYGON ((398241.4915591855 128058.1179356077,...
# 2759  234509  440168627  POLYGON ((398255.3707220157 127869.9255039312,...
# 2760  234510  440168628  POLYGON ((398219.0470580096 127959.2494262712,...
# 2761  234511  440168629  POLYGON ((398348.0023440944 127852.4554365369,...
# 2762  234512  440168630  POLYGON ((398309.1679346401 127942.3122984535,...
# 2763  234513  440168631  POLYGON ((398214.5633649268 128024.5888791713,...
# 2764  234514  440168632  POLYGON ((398279.6765682062 127903.1888448143,...
# 2765  234515  440168633  POLYGON ((398288.8777701584 127843.9537782185,...
# 2766  234516  440168634  POLYGON ((398282.0105547655 127973.7551852946,...
# 2767  234517  440168635  POLYGON ((398160.2616014996 127949.7828931023,...
# 2768  234518  440168636  POLYGON ((398193.7770337553 127925.3426504548,...
# 2769  234519  440168927  POLYGON ((398089.919480613 127877.1790639843, ...
# 2770  234520  440168928  POLYGON ((398075.7321567495 127888.6494679162,...
# 2771  234521  440168929  POLYGON ((398150.9417923637 127830.9414854747,...
# 2772  234522  440168930  POLYGON ((398104.5324924593 127866.1970124992,...
# 2773  234523  440168931  POLYGON ((398165.7372192376 127819.4155731328,...
# 2774  234524  440168932  POLYGON ((398059.9555799466 127899.8094679386,...
# 2775  234525  440168933  POLYGON ((398121.0730937348 127853.6715405456,...
# 2776  234526  440168934  POLYGON ((398135.486499843 127842.8894055216, ...
# 2777  234527  440171114  POLYGON ((397937.6356162524 127757.5300032039,...
# 2778  234528  440171116  POLYGON ((397949.2416913671 127771.8579312711,...
# 2779  234529  440171117  POLYGON ((397951.8049060965 127776.9635675792,...
# 2780  234530  440171118  POLYGON ((397945.2544048389 127767.4187037747,...
# 2781  234532  440171120  POLYGON ((397955.8009801701 127781.8357215044,...
# 2782  234829  441438985  POLYGON ((399699.9769854986 137310.1423340366,...
# 2783  234831  441636352  POLYGON ((399695.5104297972 136421.4234849207,...
# 2784  236023  448360212  POLYGON ((398994.9172866218 137255.695468859, ...
# 2785  236024  448362183  POLYGON ((398957.120727236 137225.8613854659, ...
#
#                area        boundary          place       landuse
# 0      12413.752029                         island
# 1      40706.591935                         island
# 2       8944.567758                         island
# 3      19901.898183                         island
# 4       4788.112175                         island
# 5      39400.094792                                  residential
# 6     136464.764601                                     cemetery
# 7      44434.652498                                       retail
# 8      45269.587331                                       retail
# 9       8302.074457                                        grass
# 10      6248.912406                                         park
# 11      3967.161348                                         park
# 12     19422.851233                                     cemetery
# 13    216453.370487                                       retail
# 14    299554.420074  administrative
# 15    143182.870095                                     cemetery
# 16      8343.878250                                  residential
# 17     24776.013366                                  residential
# 18     26922.325846                                  residential
# 19     11957.294581                                  residential
# 20     11421.190584                                  residential
# 21      4839.903062                                  residential
# 22     15556.651581                                  residential
# 23     15305.362327                                  residential
# 24     12677.716466                                  residential
# 25      9759.258243                                  residential
# 26      5433.486029                                  residential
# 27      8933.971269                                  residential
# 28     19631.497349                                  residential
# 29     25345.401312                                  residential
# ...             ...             ...            ...           ...
# 2756     975.458433                                        basin
# 2757     985.767199                                        basin
# 2758    1074.790542                                        basin
# 2759    1032.867505                                        basin
# 2760    1001.388339                                        basin
# 2761    1074.016693                                        basin
# 2762    1036.911721                                        basin
# 2763    1056.837428                                        basin
# 2764    1054.757998                                        basin
# 2765    1036.503266                                        basin
# 2766     988.685169                                        basin
# 2767     974.273313                                        basin
# 2768    1062.436746                                        basin
# 2769    2310.197227                                        basin
# 2770    2280.557880                                        basin
# 2771    2296.190775                                        basin
# 2772    2398.090484                                        basin
# 2773    2107.604774                                        basin
# 2774    2182.170600                                        basin
# 2775    2399.038646                                        basin
# 2776    2428.327321                                        basin
# 2777     132.532728                                        basin
# 2778     124.619846                                        basin
# 2779     124.535559                                        basin
# 2780     132.536978                                        basin
# 2781     115.260174                                        basin
# 2782    5364.560085                                 construction
# 2783  670521.704480                  neighbourhood
# 2784     615.711689                                  residential
# 2785    1462.883068                                  residential
#
# [2786 rows x 7 columns]

# %%
filters(OSM_DATA.get_osm_way_by_id(51858784), have_one, donthave)
# Out:
# False
