# %%
js_path = '../data/foursquare-taxonomy.json'
import json
with open(js_path) as f:
    JS = json.load(f)

# %%
def parse_categories(js,parent_id,level):
    result = []
    for order,cate in enumerate(js):
        cid, pluralName, shortName, name, icon = cate['id'], cate['pluralName'], cate['shortName'], cate['name'], cate['icon']        
        sub_result=[]
        if 'categories' in cate and cate['categories']:
            sub_result = parse_categories(cate['categories'], cid, level+1)
        result.append([parent_id, cid, pluralName.strip(), shortName.strip(), name.strip(), icon, level,order])
        result.extend(sub_result)
#         break
    return result
import pandas as pd
df = pd.DataFrame(parse_categories(JS,'root',1))
df.columns = ['parent_id', 'cid', 'pluralName', 'shortName', 'name', 'icon', 'level','order']

# %%
for i in range(1,4):
    sub_df = df.query('level==%d' %i)
    print sub_df.shape, sub_df.parent_id.value_counts().shape
# Out:
# (10, 8) (1L,)
# (429, 8) (10L,)
# (167, 8) (29L,)

# %%
(df.name==df.pluralName).value_counts()
# Out:
# False    585
# True      21
# dtype: int64

# %%
df.drop('icon', axis=1).to_csv('../data/frsq/frsq_taxonomy_tree')
# Out:
#                     parent_id                       cid  \
# 0                        root  4d4b7104d754a06370d81259
# 1    4d4b7104d754a06370d81259  4fceea171983d5d06c3e9823
# 2    4d4b7104d754a06370d81259  4bf58dd8d48988d1e1931735
# 3    4d4b7104d754a06370d81259  4bf58dd8d48988d1e2931735
# 4    4d4b7104d754a06370d81259  4bf58dd8d48988d1e4931735
# 5    4d4b7104d754a06370d81259  4bf58dd8d48988d17c941735
# 6    4d4b7104d754a06370d81259  52e81612bcbc57f1066b79e7
# 7    4d4b7104d754a06370d81259  4bf58dd8d48988d18e941735
# 8    4d4b7104d754a06370d81259  5032792091d4c4b30a586d5c
# 9    4d4b7104d754a06370d81259  52e81612bcbc57f1066b79ef
# 10   4d4b7104d754a06370d81259  52e81612bcbc57f1066b79e8
# 11   4d4b7104d754a06370d81259  4bf58dd8d48988d1f1931735
# 12   4d4b7104d754a06370d81259  52e81612bcbc57f1066b79ea
# 13   4d4b7104d754a06370d81259  4deefb944765f83613cdba6e
# 14   4d4b7104d754a06370d81259  52e81612bcbc57f1066b79e6
# 15   4d4b7104d754a06370d81259  52e81612bcbc57f1066b79eb
# 16   4d4b7104d754a06370d81259  4bf58dd8d48988d17f941735
# 17   4bf58dd8d48988d17f941735  4bf58dd8d48988d17e941735
# 18   4bf58dd8d48988d17f941735  4bf58dd8d48988d180941735
# 19   4d4b7104d754a06370d81259  4bf58dd8d48988d181941735
# 20   4bf58dd8d48988d181941735  4bf58dd8d48988d18f941735
# 21   4bf58dd8d48988d181941735  4bf58dd8d48988d190941735
# 22   4bf58dd8d48988d181941735  4bf58dd8d48988d192941735
# 23   4bf58dd8d48988d181941735  4bf58dd8d48988d191941735
# 24   4d4b7104d754a06370d81259  4bf58dd8d48988d1e5931735
# 4                 Bowling Alleys            Bowling Alley
# 5                        Casinos                   Casino
# 6                       Circuses                   Circus
# 7                   Comedy Clubs              Comedy Club
# 8                  Concert Halls             Concert Hall
# 9            Country Dance Clubs       Country Dance Club
# 10             Disc Golf Courses                Disc Golf
# 11         General Entertainment            Entertainment
# 12                Go Kart Tracks                  Go Kart
# 13                Historic Sites            Historic Site
# 14              Laser Tag Places                Laser Tag
# 15             Mini Golf Courses                Mini Golf
# 16                Movie Theaters            Movie Theater
# 17          Indie Movie Theaters            Indie Theater
# 18                   Multiplexes                 Cineplex
# 19                       Museums                   Museum
# 20                   Art Museums               Art Museum
# 21               History Museums           History Museum
# 22                  Planetariums              Planetarium
# 23               Science Museums           Science Museum
# 24                  Music Venues              Music Venue
# 25                    Jazz Clubs                Jazz Club
# 26                    Piano Bars                Piano Bar
# 27                    Rock Clubs                Rock Club
# 28            Outdoor Sculptures        Outdoor Sculpture
# 29        Performing Arts Venues          Performing Arts
# ..                           ...                      ...
# 576                       Hotels                    Hotel
# 577             Bed & Breakfasts                    B & B
# 578              Boarding Houses                 Boarding
# 579                      Hostels                   Hostel
# 580                  Hotel Pools                     Pool
# 581                       Motels                    Motel
# 582                      Resorts                   Resort
# 583                   Roof Decks                Roof Deck
# 584                Intersections             Intersection
# 585                  Light Rails               Light Rail
# 586               Moving Targets            Moving Target
# 587                         Pier                     Pier
# 588                     RV Parks                  RV Park
# 589         Rental Car Locations               Rental Car
# 590                   Rest Areas               Rest Areas
# 591                        Roads                     Road
# 592                      Streets                   Street
# 593                      Subways                   Subway
# 594                  Taxi Stands               Taxi Stand
# 595                        Taxis                     Taxi
# 596                  Toll Booths               Toll Booth
# 597                  Toll Plazas               Toll Plaza
# 598  Tourist Information Centers      Tourist Information
# 599               Train Stations            Train Station
# 600                    Platforms                 Platform
# 601                       Trains                    Train
# 602                        Trams                     Tram
# 603      Transportation Services  Transportation Services
# 604               Travel Lounges                   Lounge
# 605                      Tunnels                   Tunnel
#
#                            name  \
# 0          Arts & Entertainment
# 1                      Aquarium
# 2                        Arcade
# 3                   Art Gallery
# 4                 Bowling Alley
# 5                        Casino
# 6                        Circus
# 7                   Comedy Club
# 8                  Concert Hall
# 9            Country Dance Club
# 10                    Disc Golf
# 11        General Entertainment
# 12                Go Kart Track
# 13                Historic Site
# 14                    Laser Tag
# 15                    Mini Golf
# 16                Movie Theater
# 17          Indie Movie Theater
# 18                    Multiplex
# 19                       Museum
# 20                   Art Museum
# 21               History Museum
# 22                  Planetarium
# 23               Science Museum
# 24                  Music Venue
# 25                    Jazz Club
# 26                    Piano Bar
# 27                    Rock Club
# 28            Outdoor Sculpture
# 29        Performing Arts Venue
# ..                          ...
# 576                       Hotel
# 577             Bed & Breakfast
# 578              Boarding House
# 579                      Hostel
# 580                  Hotel Pool
# 581                       Motel
# 582                      Resort
# 583                   Roof Deck
# 584                Intersection
# 585                  Light Rail
# 586               Moving Target
# 587                        Pier
# 588                     RV Park
# 589         Rental Car Location
# 590                   Rest Area
# 591                        Road
# 592                      Street
# 593                      Subway
# 594                  Taxi Stand
# 595                        Taxi
# 596                  Toll Booth
# 597                  Toll Plaza
# 598  Tourist Information Center
# 599               Train Station
# 600                    Platform
# 601                       Train
# 602                        Tram
# 603      Transportation Service
# 604               Travel Lounge
# 605                      Tunnel
#
#                                                   icon  level  order
# 0    {u'prefix': u'https://ss3.4sqi.net/img/categor...      1      0
# 1    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      0
# 2    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      1
# 3    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      2
# 4    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      3
# 5    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      4
# 6    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      5
# 7    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      6
# 8    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      7
# 9    {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      8
# 10   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      9
# 11   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     10
# 12   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     11
# 13   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     12
# 14   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     13
# 15   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     14
# 16   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     15
# 17   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      0
# 18   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      1
# 19   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     16
# 20   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      0
# 21   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      1
# 22   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      2
# 23   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      3
# 24   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     17
# 25   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      0
# 26   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      1
# 27   {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      2
# 28   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     18
# 29   {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     19
# ..                                                 ...    ...    ...
# 576  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      8
# 577  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      0
# 578  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      1
# 579  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      2
# 580  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      3
# 581  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      4
# 582  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      5
# 583  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      6
# 584  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2      9
# 585  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     10
# 586  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     11
# 587  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     12
# 588  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     13
# 589  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     14
# 590  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     15
# 591  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     16
# 592  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     17
# 593  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     18
# 594  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     19
# 595  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     20
# 596  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     21
# 597  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     22
# 598  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     23
# 599  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     24
# 600  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      0
# 601  {u'prefix': u'https://ss3.4sqi.net/img/categor...      3      1
# 602  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     25
# 603  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     26
# 604  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     27
# 605  {u'prefix': u'https://ss3.4sqi.net/img/categor...      2     28
#
# [606 rows x 8 columns]

# %%
with open('frsq_taxonomy_tree.txt','w') as f:
    f.write('\n'.join(df.apply(lambda x:'{}{}'.format('\t'*x.level, x['name'].encode('utf-8')), axis=1).values))

# %%
df.groupby('parent_id').apply(list)
# Out:
# parent_id
# 4bf58dd8d48988d103951735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d104941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d10f941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d124941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d126941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d129951735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d131941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d13b941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d145941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d150941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d175941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d17f941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d181941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d182941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d184941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d198941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1b4941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1be941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1e2941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1e5931735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1e9941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1ed931735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1f2931735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1f9941735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1fa931735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1fe931735    [parent_id, cid, pluralName, shortName, name, ...
# 4bf58dd8d48988d1ff931735    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7104d754a06370d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06372d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06373d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06374d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06375d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06376d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06377d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06378d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4d4b7105d754a06379d81259    [parent_id, cid, pluralName, shortName, name, ...
# 4e67e38e036454776db1fb3a    [parent_id, cid, pluralName, shortName, name, ...
# 4f4528bc4b90abdf24c9de85    [parent_id, cid, pluralName, shortName, name, ...
# 530e33ccbcbc57f1066bbfe4    [parent_id, cid, pluralName, shortName, name, ...
# none                        [parent_id, cid, pluralName, shortName, name, ...
# dtype: object
